# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import plotly.express as iplot

# %%
df = pd.read_excel("C:\\Users\\manis\\OneDrive\\Documents\\imports and exports.xlsx")

# %%
df.head()
# Out:
#        Country  Export  Import  Total Trade  Trade Balance  Year(start)  \
# 0  AFGHANISTAN   21.25   10.70        31.95          10.55           97
# 1  AFGHANISTAN   12.81   28.14        40.95         -15.33           98
# 2  AFGHANISTAN   33.20   21.06        54.26          12.15           99
# 3  AFGHANISTAN   25.86   26.59        52.45          -0.73         2000
# 4  AFGHANISTAN   24.37   17.52        41.89           6.85         2001
#
#    Year(end)
# 0         98
# 1         99
# 2       2000
# 3       2001
# 4       2002

# %%
df.shape
# Out:
# (5767, 7)

# %%
df.isnull().sum()
# Out:
# Country            0
# Export             8
# Import           532
# Total Trade      566
# Trade Balance    566
# Year(start)        0
# Year(end)          0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (5201, 7)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Country'].unique()
# Out:
# array(['AFGHANISTAN', 'ALBANIA', 'ALGERIA', 'AMERI SAMOA', 'ANDORRA',
#        'ANGOLA', 'ANGUILLA', 'ANTARTICA', 'ANTIGUA', 'ARGENTINA',
#        'ARMENIA', 'ARUBA', 'AUSTRALIA', 'AUSTRIA', 'AZERBAIJAN',
#        'BAHAMAS', 'BAHARAIN IS', 'BANGLADESH PR', 'BARBADOS', 'BELARUS',
#        'BELGIUM', 'BELIZE', 'BENIN', 'BERMUDA', 'BHUTAN', 'BOLIVIA',
#        'BOSNIA-HRZGOVIN', 'BOTSWANA', 'BR VIRGN IS', 'BRAZIL', 'BRUNEI',
#        'BULGARIA', 'BURKINA FASO', 'BURUNDI', 'C AFRI REP', 'CAMBODIA',
#        'CAMEROON', 'CANADA', 'CANARY IS', 'CAPE VERDE IS', 'CAYMAN IS',
#        'CHAD', 'CHANNEL IS', 'CHILE', 'CHINA P RP', 'CHRISTMAS IS.',
#        'COCOS IS', 'COLOMBIA', 'COMOROS', 'CONGO D. REP.', 'CONGO P REP',
#        'COOK IS', 'COSTA RICA', "COTE D' IVOIRE", 'CROATIA', 'CUBA',
#        'CYPRUS', 'CZECH REPUBLIC', 'DENMARK', 'DJIBOUTI', 'DOMINIC REP',
#        'DOMINICA', 'ECUADOR', 'EGYPT A RP', 'EL SALVADOR', 'EQUTL GUINEA',
# ...

# %%
df['Country'].value_counts().sum()
# Out:
# 5201

# %%
df['Country'].value_counts().head(10)
# Out:
# AFGHANISTAN    25
# LITHUANIA      25
# MACEDONIA      25
# MADAGASCAR     25
# MALAWI         25
# MALAYSIA       25
# MALDIVES       25
# MALI           25
# MALTA          25
# MAURITIUS      25
# Name: Country, dtype: int64

# %%
df['Year(start)'].unique()
# Out:
# array([  97,   98,   99, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020, 2021], dtype=int64)

# %%
df['Year(end)'].unique()
# Out:
# array([  98,   99, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#        2020, 2021, 2022], dtype=int64)

# %%
df['Export'].max() , df['Export'].min()
# Out:
# (55786.38, 0.0)

# %%
df['Import'].max() , df['Import'].min()
# Out:
# (76380.7, 0.0)

# %%
df['Export'].mean()
# Out:
# 905.4182945587387

# %%
df.iloc[2344]
# Out:
# Country          KAZAKHSTAN
# Export                81.42
# Import                15.39
# Total Trade           96.81
# Trade Balance         66.03
# Year(start)            2004
# Year(end)              2005
# Name: 2604, dtype: object

# %% [markdown]
# high_exports = (df['Export'] > 905)

# %%
high_exports = (df['Export'] > 20000)

# %%
df.loc[high_exports].head(10)
# Out:
#           Country    Export    Import  Total Trade  Trade Balance  \
# 1084   CHINA P RP  21187.15  65212.25     86399.40      -44025.10
# 5345  U ARAB EMTS  24477.48  23791.25     48268.72         686.23
# 5346  U ARAB EMTS  23970.40  19499.10     43469.50        4471.30
# 5347  U ARAB EMTS  33822.39  32753.16     66575.55        1069.22
# 5348  U ARAB EMTS  35925.52  36756.32     72681.84        -830.80
# 5349  U ARAB EMTS  36316.65  39138.36     75455.01       -2821.72
# 5350  U ARAB EMTS  30520.42  29019.82     59540.24        1500.60
# 5351  U ARAB EMTS  33028.08  26139.91     59167.99        6888.17
# 5352  U ARAB EMTS  30316.50  19445.68     49762.18       10870.82
# 5353  U ARAB EMTS  31175.50  21509.83     52685.33        9665.67
#
#       Year(start)  Year(end)
# 1084         2020       2021
# 5345         2008       2009
# 5346         2009       2010
# 5347         2010       2011
# 5348         2011       2012
# 5349         2012       2013
# ...

# %%
df2 = df.loc[high_exports , ['Country','Year(start)', 'Year(end)']]
df2
# Out:
#           Country  Year(start)  Year(end)
# 1084   CHINA P RP         2020       2021
# 5345  U ARAB EMTS         2008       2009
# 5346  U ARAB EMTS         2009       2010
# 5347  U ARAB EMTS         2010       2011
# 5348  U ARAB EMTS         2011       2012
# 5349  U ARAB EMTS         2012       2013
# 5350  U ARAB EMTS         2013       2014
# 5351  U ARAB EMTS         2014       2015
# 5352  U ARAB EMTS         2015       2016
# 5353  U ARAB EMTS         2016       2017
# 5354  U ARAB EMTS         2017       2018
# 5355  U ARAB EMTS         2018       2019
# 5356  U ARAB EMTS         2019       2020
# 5358  U ARAB EMTS         2021       2022
# 5394        U S A         2007       2008
# 5395        U S A         2008       2009
# 5397        U S A         2010       2011
# 5398        U S A         2011       2012
# 5399        U S A         2012       2013
# 5400        U S A         2013       2014
# 5401        U S A         2014       2015
# ...

# %%
import seaborn as sb
sb.relplot(data=df2,x='Country',y='Year(start)',kind='line')

# %%
sb.relplot(data=df2,x='Country',y='Year(start)',kind='scatter')

# %%
df['Year(start)'].unique()
# Out:
# array([  97,   98,   99, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020, 2021], dtype=int64)

# %%
plt.figure(figsize = (13,8))
plt.xticks(rotation = 90)
sb.lineplot(data=df,x='Year(start)',y='Total Trade')
# Out:
# <AxesSubplot:xlabel='Year(start)', ylabel='Total Trade'>

# %%
df['Total Trade'].max()
# Out:
# 89714.23

# %%
df['Total Trade'].mean()
# Out:
# 2240.6393039800037

# %%
high_trade = (df['Total Trade'] > 10000)
df3 = df.loc[high_trade]
df3
# Out:
#               Country   Export    Import  Total Trade  Trade Balance  \
# 289         AUSTRALIA  1439.32  11098.07     12537.39       -9658.75
# 290         AUSTRALIA  1384.96  12407.37     13792.33      -11022.41
# 291         AUSTRALIA  1713.02  10789.00     12502.01       -9075.98
# 292         AUSTRALIA  2476.84  15578.52     18055.35      -13101.68
# 293         AUSTRALIA  2348.65  13085.70     15434.34      -10737.05
# ...               ...      ...       ...          ...            ...
# 5639  VIETNAM SOC REP  7813.08   5018.55     12831.64        2794.53
# 5640  VIETNAM SOC REP  6507.38   7192.23     13699.61        -684.86
# 5641  VIETNAM SOC REP  5059.90   7283.42     12343.32       -2223.53
# 5642  VIETNAM SOC REP  4999.64   6120.66     11120.30       -1121.02
# 5643  VIETNAM SOC REP  5105.88   5075.21     10181.09          30.67
#
#       Year(start)  Year(end)
# 289          2008       2009
# 290          2009       2010
# 291          2010       2011
# ...

# %%
df['Country'].value_counts()
# Out:
# AFGHANISTAN                              25
# NICARAGUA                                25
# MONTSERRAT                               25
# MOROCCO                                  25
# MOZAMBIQUE                               25
#                                          ..
# GUERNSEY                                  4
# INSTALLATIONS IN INTERNATIONAL WATERS     3
# CURACAO                                   2
# JERSEY                                    2
# SVALLBARD AND J                           1
# Name: Country, Length: 250, dtype: int64

# %%
df3['Country'].unique()
# Out:
# array(['AUSTRALIA', 'BANGLADESH PR', 'BELGIUM', 'BRAZIL', 'CHINA P RP',
#        'FRANCE', 'GERMANY', 'HONG KONG', 'INDONESIA', 'IRAN', 'IRAQ',
#        'ITALY', 'JAPAN', 'KOREA RP', 'KUWAIT', 'MALAYSIA', 'NETHERLAND',
#        'NIGERIA', 'QATAR', 'RUSSIA', 'SAUDI ARAB', 'SINGAPORE',
#        'SOUTH AFRICA', 'SWITZERLAND', 'THAILAND', 'U ARAB EMTS', 'U K',
#        'U S A', 'UNSPECIFIED', 'VENEZUELA', 'VIETNAM SOC REP'],
#       dtype=object)

# %%
plt.figure(figsize = (13,8))
plt.xticks(rotation = 90)
plt.title('COUNTRY VS TOTAL TRADE')
sb.barplot(data=df3,x='Country',y='Total Trade') #china has higest trademark
# Out:
# <AxesSubplot:title={'center':'COUNTRY VS TOTAL TRADE'}, xlabel='Country', ylabel='Total Trade'>

# %%
plt.figure(figsize = (13,8))
plt.xticks(rotation = 90)
sb.lineplot(data=df3,x='Country',y='Total Trade')
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Total Trade'>

# %%
plt.figure(figsize = (13,8))
plt.xticks(rotation = 90)
plt.title('COUNTRY VS TRADE BALANCE')
sb.barplot(data=df3,x='Country',y='Trade Balance')
# Out:
# <AxesSubplot:title={'center':'COUNTRY VS TRADE BALANCE'}, xlabel='Country', ylabel='Trade Balance'>

# %%
plt.figure(figsize = (13,8))
plt.xticks(rotation = 90)
plt.title('COUNTRY VS TRADE BALANCE')
sb.lineplot(data=df3,x='Country',y='Trade Balance')
# Out:
# <AxesSubplot:title={'center':'COUNTRY VS TRADE BALANCE'}, xlabel='Country', ylabel='Trade Balance'>

# %%
df4 = (df3['Total Trade'] > 30000)
df3.loc[df4]
# Out:
#           Country    Export    Import  Total Trade  Trade Balance  \
# 1071   CHINA P RP  10871.34  27146.41     38017.74      -16275.07
# 1072   CHINA P RP   9353.50  32497.02     41850.52      -23143.52
# 1073   CHINA P RP  11617.88  30824.02     42441.90      -19206.14
# 1074   CHINA P RP  14168.86  43479.76     57648.62      -29310.90
# 1075   CHINA P RP  18076.55  55313.58     73390.13      -37237.02
# 1076   CHINA P RP  13534.88  52248.33     65783.21      -38713.45
# 1077   CHINA P RP  14824.36  51034.62     65858.98      -36210.26
# 1078   CHINA P RP  11934.25  60413.17     72347.42      -48478.91
# 1079   CHINA P RP   9011.36  61707.95     70719.31      -52696.60
# 1080   CHINA P RP  10171.89  61283.03     71454.93      -51111.14
# 1081   CHINA P RP  13333.53  76380.70     89714.23      -63047.16
# 1082   CHINA P RP  16752.20  70319.64     87071.84      -53567.43
# 1083   CHINA P RP  16612.75  65260.75     81873.50      -48647.99
# ...

# %%
plt.figure(figsize = (13,8))
plt.xticks(rotation = 90)
plt.title('COUNTRY VS EXPORTS')
sb.barplot(data=df3,x='Country',y='Export')
# Out:
# <AxesSubplot:title={'center':'COUNTRY VS EXPORTS'}, xlabel='Country', ylabel='Export'>

# %%
df5 = (df['Year(start)'] > 2020)
df.loc[df5]
# Out:
#             Country  Export  Import  Total Trade  Trade Balance  Year(start)  \
# 24      AFGHANISTAN  401.72  412.78       814.50         -11.06         2021
# 49          ALBANIA   44.64   26.44        71.08          18.19         2021
# 74          ALGERIA  525.67  545.10      1070.76         -19.43         2021
# 99      AMERI SAMOA    0.62    0.00         0.62           0.62         2021
# 124         ANDORRA    0.05     NaN          NaN            NaN         2021
# ...             ...     ...     ...          ...            ...          ...
# 5668   VIRGIN IS US    3.54    0.39         3.93           3.15         2021
# 5691    WALLIS F IS    0.00     NaN          NaN            NaN         2021
# 5716  YEMEN REPUBLC  541.78   89.63       631.41         452.15         2021
# 5741         ZAMBIA  258.64   99.97       358.62         158.67         2021
# 5766       ZIMBABWE  148.89    1.69       150.58         147.20         2021
#
#       Year(end)
# 24         2022
# ...
